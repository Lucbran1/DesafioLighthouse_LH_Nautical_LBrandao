# %% [markdown]
# # LH Nautical – Data Analysis
#
# Autor: Luciano Brandao
#
# Este notebook apresenta a análise dos dados da LH Nautical com o objetivo de
# organizar os dados, gerar insights de negócio e propor modelos preditivos.

# %% [markdown]
# ## 1. Contexto do Problema

# %% [markdown]
# ## 2. Carregamento dos Dados

# %% [markdown]
# ## 3. Exploração Inicial (EDA)

# %% [markdown]
# ## 4. Limpeza e Tratamento de Dados

# %% [markdown]
# ## 5. Análise de Vendas

# %% [markdown]
# ## 6. Análise de Clientes

# %% [markdown]
# ## 7. Previsão de Demanda

# %% [markdown]
# ## 8. Sistema de Recomendação

# %% [markdown]
# ## 9. Insights de Negócio

# %% [markdown]
# ## 10. Conclusão
